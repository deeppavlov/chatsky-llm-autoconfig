# %%
import json
from chatsky_llm_autoconfig.graph import Graph
from chatsky_llm_autoconfig.algorithms.dialogue_generation import DialoguePathSampler

# %%
with open('complex_graphs.json', encoding="utf-8") as f:
    data = json.load(f)
print(len(data))
# Out:
# 1

# %%
g = Graph(graph_dict=data[0]['graph'])
g.visualise()

# %%
d = DialoguePathSampler()
dials = d.invoke(g)
print(dials[2])
# Out:
# assistant: Good evening, how can I help?
# user: I want to book a duplex room
# assistant: How long are you going to stay?
# user: Three nights
# assistant: Unfortunately we do not have a vacant room for these dates, but we can offer two separate single rooms. Would this be acceptable?
# user: No, thanks, this does not suit me
# assistant: Can I help you with anything else?
# user: No, thanks
# assistant: Okay, goodbye!
