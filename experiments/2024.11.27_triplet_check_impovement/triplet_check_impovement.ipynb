# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Test Graph Creation

# %%
from langchain.prompts import PromptTemplate

cycle_graph_one_utter = PromptTemplate.from_template(
    '''
    Create a natural dialogue graph that represents any business conversation with logical cycles.

    Here's an example of a clothing store conversation flow:

    ```mermaid
    graph TD
        1[Welcome] -->|"Looking for jeans"| 2[Ask Preferences]
        2 -->|"Slim fit, blue"| 3[Offer Options]
        3 -->|"Like the first one"| 4[Size Check]
        4 -->|"Size 32"| 5[Location]
        5 -->|"Try in store"| 6[Complete]
        6 -->|"Look for something else"| 2
    ```

    Example JSON structure:
    {{
        "edges": [
            {{ "source": 1, "target": 2, "utterances": ["I'm looking for jeans"] }},
            {{ "source": 2, "target": 3, "utterances": ["I'd like slim fit in blue"] }},
            {{ "source": 3, "target": 4, "utterances": ["I like the first option"] }},
            {{ "source": 4, "target": 5, "utterances": ["Size 32 please"] }},
            {{ "source": 5, "target": 6, "utterances": ["I'll try them in store"] }},
            {{ "source": 6, "target": 2, "utterances": ["I'd like to look for another pair"] }}
        ],
        "nodes": [
            {{ "id": 1, "label": "welcome", "is_start": true,
              "utterances": ["Welcome to Style Store! How can I help you today?"] }},
            {{ "id": 2, "label": "ask_preferences", "is_start": false,
              "utterances": ["What style and color are you interested in?"] }},
            {{ "id": 3, "label": "offer_options", "is_start": false,
              "utterances": ["I have these slim fit blue jeans available. Would you like to see them?"] }},
            {{ "id": 4, "label": "check_size", "is_start": false,
              "utterances": ["What size would you like?"] }},
            {{ "id": 5, "label": "location_preference", "is_start": false,
              "utterances": ["Would you like to try them in store or have them delivered?"] }},
            {{ "id": 6, "label": "complete", "is_start": false,
              "utterances": ["Perfect! The jeans are ready for you. Would you like to look for anything else?"] }}
        ]
    }}

    Key points:
    1. Keep responses natural and contextual
    2. Each state should serve a clear purpose
    3. Return cycles should make conversational sense
    4. Nodes are assistant phrases, edges are user responses. We start with assistant node. We end with assistant node.

    Create a dialogue graph for topic: {topic}
    Return only valid JSON matching the format above.
    '''
)


cycle_graph_two_utter = PromptTemplate.from_template(
    '''
    Create a natural dialogue graph that represents any business conversation with logical cycles.
    Each node and edge should contain exactly 2 utterances that mean the same thing but are phrased differently.

    Here's an example of an ordering conversation flow:

    ```mermaid
    graph TD
        1[Welcome] -->|"Want to order"| 2[Ask Item]
        2 -->|"Pizza please"| 3[Size Options]
        3 -->|"Large size"| 4[Confirm]
        4 -->|"That's correct"| 5[Complete]
        5 -->|"More items"| 2
    ```

    Example JSON structure:
    {{
        "edges": [
            {{ "source": 1, "target": 2, "utterances": [
                "I need to make an order",
                "I want to order from you"
            ]}},
            {{ "source": 2, "target": 3, "utterances": [
                "I'd like a pizza",
                "A pizza please"
            ]}},
            {{ "source": 3, "target": 4, "utterances": [
                "Large size please",
                "I want it large"
            ]}},
            {{ "source": 4, "target": 5, "utterances": [
                "Yes, that's right",
                "Yes, that's correct"
            ]}},
            {{ "source": 5, "target": 2, "utterances": [
                "I want to order more",
                "I'd like to add something else"
            ]}}
        ],
        "nodes": [
            {{ "id": 1, "label": "welcome", "is_start": true,
              "utterances": [
                "How can I help you today?",
                "What can I do for you today?"
            ]}},
            {{ "id": 2, "label": "ask_item", "is_start": false,
              "utterances": [
                "What would you like to order?",
                "What can I get for you?"
            ]}},
            {{ "id": 3, "label": "size_options", "is_start": false,
              "utterances": [
                "What size would you like?",
                "Which size do you prefer?"
            ]}},
            {{ "id": 4, "label": "confirm", "is_start": false,
              "utterances": [
                "So that's a large pizza, is that correct?",
                "You want a large pizza, right?"
            ]}},
            {{ "id": 5, "label": "complete", "is_start": false,
              "utterances": [
                "Done. Anything else?",
                "Okay. Anything else?"
            ]}}
        ]
    }}

    Key points:
    1. Each node and edge must have exactly 2 utterances
    2. The two utterances must mean the same thing, just phrased differently
    3. Keep responses natural and contextual
    4. Each state should serve a clear purpose
    5. Return cycles should make conversational sense
    6. Nodes are assistant phrases, edges are user responses
    7. We start with assistant node and end with assistant node

    Create a dialogue graph for topic: {topic}
    Return only valid JSON matching the format above.
    '''
)

# %%
from chatsky_llm_autoconfig.algorithms.dialogue_generation import DialogueSampler
from chatsky_llm_autoconfig.algorithms.topic_graph_generation import CycleGraphGenerator
from chatsky_llm_autoconfig.metrics.llm_metrics import are_triplets_valid
from langchain_openai import ChatOpenAI
from typing import List, Dict, Any, Tuple
import os
import json
from datetime import datetime
from pathlib import Path

def generate_and_validate_dialogues(
    topics: List[str],
    output_dir: str = "generated_datasets_two_utter"
) -> Tuple[List[Dict[str, Any]], List[Dict[str, Any]]]:
    # Create output directory if it doesn't exist
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    # Initialize components with two utterance prompt
    graph_generator = CycleGraphGenerator(prompt=cycle_graph_two_utter)
    sampler = DialogueSampler()
    
    model = ChatOpenAI(
        model='gpt-4',
        api_key=os.getenv("OPENAI_API_KEY"),
        base_url=os.getenv("OPENAI_BASE_URL"),
        temperature=0
    )
    
    valid_results = []
    invalid_results = []
    
    for topic in topics:
        try:
            # Generate graph and validate
            graph = graph_generator.invoke(topic=topic)
            validation_result = are_triplets_valid(graph, model, topic)
            
            print(f"Topic: {topic}")
            print(f"Validation result: {validation_result}")
            
            # Sample dialogue from the graph
            sampled_dialogue = sampler.invoke(graph, 1, -1)[0]
            
            result_entry = {
                "graph": graph.graph_dict,
                "topic": topic,
                "dialogues": [sampled_dialogue.model_dump()],
                "validation_result": validation_result
            }
            
            # Sort into valid/invalid collections
            if validation_result["value"]:
                valid_results.append(result_entry)
                print(f"✅ Valid dialogue generated for topic: {topic} (double utterance)")
            else:
                invalid_results.append(result_entry)
                print(f"❌ Invalid dialogue generated for topic: {topic} (double utterance)")
                
        except Exception as e:
            print(f"Error processing topic {topic}: {str(e)}")
            continue
    
    # Save results to JSON files with timestamp
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    
    valid_file = Path(output_dir) / f"valid_dialogues_two_utter_{timestamp}.json"
    invalid_file = Path(output_dir) / f"invalid_dialogues_two_utter_{timestamp}.json"
    
    with open(valid_file, 'w', encoding='utf-8') as f:
        json.dump(valid_results, f, ensure_ascii=False, indent=2)
    
    with open(invalid_file, 'w', encoding='utf-8') as f:
        json.dump(invalid_results, f, ensure_ascii=False, indent=2)
        
    print(f"\nGeneration Summary (Double Utterance):")
    print(f"Valid dialogues: {len(valid_results)}")
    print(f"Invalid dialogues: {len(invalid_results)}")
    print(f"\nResults saved to:")
    print(f"Valid: {valid_file}")
    print(f"Invalid: {invalid_file}")
    
    return valid_results, invalid_dialogues

# Extended list of topics
topics = [
    "library card registration",
    "dental appointment scheduling",
    "mobile phone plan subscription",
    "concert ticket reservation",
    "passport renewal application",
    "driving lesson booking",
    "moving service scheduling",
    "internet installation setup",
    "visa application consultation",
    "home cleaning service booking"
    "beauty salon appointment",
    "bank account opening",
]

# Generate and save the datasets
valid_dialogues, invalid_dialogues = generate_and_validate_dialogues(topics)
# Out:
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 101
#      85 topics = [
#      86     "library card registration",
#      87     "dental appointment scheduling",
#    (...)
#      97     "bank account opening",
#      98 ]
#     100 # Generate and save the datasets
# --> 101 valid_dialogues, invalid_dialogues = generate_and_validate_dialogues(topics)
#
# Cell In[6], line 36, in generate_and_validate_dialogues(topics, output_dir)
#      33 try:
#      34     # Generate graph and validate
#      35     graph = graph_generator.invoke(topic=topic)
# ---> 36     validation_result = are_triplets_valid(graph, model, topic)
#      38     print(f"Topic: {topic}")
#      39     print(f"Validation result: {validation_result}")
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/dev_packages/chatsky_llm_autoconfig/chatsky_llm_autoconfig/metrics/llm_metrics.py:102, in are_triplets_valid(G, model, topic)
#      94 input_data = {
#      95     "source_utterances": source_utterances,
#      96     "edge_utterances": edge_utterances,
#      97     "target_utterances": target_utterances,
#      98     "topic": topic,
#      99 }
#     101 triplet_check_chain = triplet_validate_prompt | model | parser
# --> 102 response = triplet_check_chain.invoke(input_data)
#     104 if not response.isValid:
#     105     overall_valid = False
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:707, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     705     generation_info = {"headers": dict(raw_response.headers)}
#     706 else:
# --> 707     response = self.client.create(**payload)
#     708 return self._create_chat_result(response, generation_info)
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/resources/chat/completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     788 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     789 def create(
#     790     self,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     828     validate_response_format(response_format)
# --> 829     return self._post(
#     830         "/chat/completions",
#     831         body=maybe_transform(
#     832             {
#     833                 "messages": messages,
#     834                 "model": model,
#     835                 "audio": audio,
#     836                 "frequency_penalty": frequency_penalty,
#     837                 "function_call": function_call,
#     838                 "functions": functions,
#     839                 "logit_bias": logit_bias,
#     840                 "logprobs": logprobs,
#     841                 "max_completion_tokens": max_completion_tokens,
#     842                 "max_tokens": max_tokens,
#     843                 "metadata": metadata,
#     844                 "modalities": modalities,
#     845                 "n": n,
#     846                 "parallel_tool_calls": parallel_tool_calls,
#     847                 "prediction": prediction,
#     848                 "presence_penalty": presence_penalty,
#     849                 "response_format": response_format,
#     850                 "seed": seed,
#     851                 "service_tier": service_tier,
#     852                 "stop": stop,
#     853                 "store": store,
#     854                 "stream": stream,
#     855                 "stream_options": stream_options,
#     856                 "temperature": temperature,
#     857                 "tool_choice": tool_choice,
#     858                 "tools": tools,
#     859                 "top_logprobs": top_logprobs,
#     860                 "top_p": top_p,
#     861                 "user": user,
#     862             },
#     863             completion_create_params.CompletionCreateParams,
#     864         ),
#     865         options=make_request_options(
#     866             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867         ),
#     868         cast_to=ChatCompletion,
#     869         stream=stream or False,
#     870         stream_cls=Stream[ChatCompletionChunk],
#     871     )
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/_base_client.py:990, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     987 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     989 try:
# --> 990     response = self._client.send(
#     991         request,
#     992         stream=stream or self._should_stream_response_body(request=request),
#     993         **kwargs,
#     994     )
#     995 except httpx.TimeoutException as err:
#     996     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
from chatsky_llm_autoconfig.algorithms.dialogue_generation import DialogueSampler
from chatsky_llm_autoconfig.graph import Graph
import json
from pathlib import Path

# Initialize sampler
sampler = DialogueSampler()

# Get all JSON files in the directory
dataset_dir = Path("generated_datasets_two_utter")
json_files = list(dataset_dir.glob("*.json"))

for json_path in json_files:
    print(f"\nProcessing file: {json_path.name}")
    print("=" * 80)
    
    # Load JSON file
    with open(json_path, "r") as f:
        data = json.load(f)

    # Process each graph
    for entry in data:
        print(f"\nTopic: {entry['topic']}")
        graph = Graph(entry["graph"])
        
        # Sample different paths
        for i in range(3):
            dialogue = sampler.invoke(graph, 1, -1)[0]
            print(f"\nPath {i+1}:")
            for message in dialogue.messages:
                print(f"- {message}")
        print("-" * 50)
# Out:
# Processing file: invalid_dialogues_two_utter_20241127_221403.json
# ================================================================================
#
# Topic: library card registration
#
# Path 1:
# - text='Welcome to the library. How can I assist you?' participant='assistant'
# - text='I want to register for a library card' participant='user'
# - text='Do you have a valid ID with you?' participant='assistant'
# - text='I have my ID with me' participant='user'
# - text='Are you a resident of the city?' participant='assistant'
# - text='I am a city resident' participant='user'
# - text="You're registered. Do you need anything else?" participant='assistant'
# - text="No, that's it" participant='user'
# - text='Thank you for registering. Have a great day!' participant='assistant'
# - text='I need to register another card' participant='user'
#
# Path 2:
# - text='Hello! What can I help you with today?' participant='assistant'
# - text="I'd like to sign up for a library card" participant='user'
# - text='Do you have a valid ID with you?' participant='assistant'
# - text='I have my ID with me' participant='user'
# - text='Do you live in the city?' participant='assistant'
# - text='Yes, I live in the city' participant='user'
# - text="You're registered. Do you need anything else?" participant='assistant'
# - text="Yes, that's all" participant='user'
# - text='Thank you for registering. Have a great day!' participant='assistant'
# - text="I'd like to sign up another person" participant='user'
#
# Path 3:
# - text='Hello! What can I help you with today?' participant='assistant'
# - text="I'd like to sign up for a library card" participant='user'
# - text='Can you provide your identification?' participant='assistant'
# - text='I have my ID with me' participant='user'
# - text='Do you live in the city?' participant='assistant'
# - text='I am a city resident' participant='user'
# - text="Great, you're all set. Anything else?" participant='assistant'
# - text="No, that's it" participant='user'
# - text='Thank you for registering. Have a great day!' participant='assistant'
# - text="I'd like to sign up another person" participant='user'
# --------------------------------------------------
#
# Topic: mobile phone plan subscription
#
# Path 1:
# - text='Hello! What can I help you with regarding mobile plans?' participant='assistant'
# - text="I'm interested in a phone plan" participant='user'
# - text='What type of plan are you looking for?' participant='assistant'
# - text='I want a plan with unlimited data' participant='user'
# - text='We have a plan with unlimited data. Does that suit you?' participant='assistant'
# - text='Yes, that works for me' participant='user'
# - text='Excellent! Shall we go ahead with this plan?' participant='assistant'
# - text="No, that's all" participant='user'
# - text="You're all set. Do you need anything else?" participant='assistant'
# - text='I want to explore more options' participant='user'
#
# Path 2:
# - text='Welcome! How can I assist you with your mobile needs?' participant='assistant'
# - text='I want to subscribe to a mobile plan' participant='user'
# - text='What kind of mobile plan do you need?' participant='assistant'
# - text='I need unlimited data' participant='user'
# - text='Our unlimited data plan might be a good fit. Is that okay?' participant='assistant'
# - text='Yes, that sounds good' participant='user'
# - text='Great choice! Would you like to proceed?' participant='assistant'
# - text="No, I'm good" participant='user'
# - text="You're all set. Do you need anything else?" participant='assistant'
# - text='I want to explore more options' participant='user'
#
# Path 3:
# - text='Hello! What can I help you with regarding mobile plans?' participant='assistant'
# - text='I want to subscribe to a mobile plan' participant='user'
# - text='What kind of mobile plan do you need?' participant='assistant'
# - text='I need unlimited data' participant='user'
# - text='Our unlimited data plan might be a good fit. Is that okay?' participant='assistant'
# - text='Yes, that works for me' participant='user'
# - text='Excellent! Shall we go ahead with this plan?' participant='assistant'
# - text="No, I'm good" participant='user'
# - text='Your subscription is complete. Anything else?' participant='assistant'
# - text="I'd like to see other plans" participant='user'
# --------------------------------------------------
#
# Topic: concert ticket reservation
#
# Path 1:
# - text='What can I do for you regarding concert tickets?' participant='assistant'
# - text='I want to book concert tickets' participant='user'
# - text='What concert would you like to attend?' participant='assistant'
# - text="I'd like tickets for the rock concert" participant='user'
# - text='How many tickets would you like to book?' participant='assistant'
# - text="I'd like to book two tickets" participant='user'
# - text='So, two tickets for the rock concert, is that correct?' participant='assistant'
# - text="That's right" participant='user'
# - text='Your reservation is complete. Anything else?' participant='assistant'
# - text='I want to book more tickets' participant='user'
#
# Path 2:
# - text='What can I do for you regarding concert tickets?' participant='assistant'
# - text="I'd like to reserve tickets for a concert" participant='user'
# - text='Which concert are you interested in?' participant='assistant'
# - text="I'm interested in the rock concert" participant='user'
# - text='How many tickets do you need?' participant='assistant'
# - text='Two tickets, please' participant='user'
# - text='You want two tickets for the rock concert, right?' participant='assistant'
# - text="That's right" participant='user'
# - text='Tickets booked. Would you like to do anything else?' participant='assistant'
# - text='I want to book more tickets' participant='user'
#
# Path 3:
# - text='What can I do for you regarding concert tickets?' participant='assistant'
# - text="I'd like to reserve tickets for a concert" participant='user'
# - text='Which concert are you interested in?' participant='assistant'
# - text="I'd like tickets for the rock concert" participant='user'
# - text='How many tickets do you need?' participant='assistant'
# - text="I'd like to book two tickets" participant='user'
# - text='So, two tickets for the rock concert, is that correct?' participant='assistant'
# - text="Yes, that's correct" participant='user'
# - text='Tickets booked. Would you like to do anything else?' participant='assistant'
# - text='I want to book more tickets' participant='user'
# --------------------------------------------------
#
# Topic: passport renewal application
#
# Path 1:
# - text='What can I help you with regarding your passport?' participant='assistant'
# - text='I want to apply for a passport renewal' participant='user'
# - text='Do you have your old passport with you?' participant='assistant'
# - text='I have my old passport with me' participant='user'
# - text='Is the application form completed?' participant='assistant'
# - text='I completed the application form' participant='user'
# - text='Have you brought a new passport photo?' participant='assistant'
# - text='Yes, I have my photo' participant='user'
# - text='Your application is complete. Anything else?' participant='assistant'
# - text="That's everything for now" participant='user'
# - text='Your renewal is processed. Enjoy your day!' participant='assistant'
#
# Path 2:
# - text='How can I assist you with your passport today?' participant='assistant'
# - text='I want to apply for a passport renewal' participant='user'
# - text='Do you have your old passport with you?' participant='assistant'
# - text='I brought my previous passport' participant='user'
# - text='Have you filled out the renewal form?' participant='assistant'
# - text='Yes, I have the form filled out' participant='user'
# - text='Do you have a recent passport photo?' participant='assistant'
# - text='Yes, I have my photo' participant='user'
# - text='Your application is complete. Anything else?' participant='assistant'
# - text="That's everything for now" participant='user'
# - text='Thank you for your application. Have a great day!' participant='assistant'
#
# Path 3:
# - text='What can I help you with regarding your passport?' participant='assistant'
# - text='I want to apply for a passport renewal' participant='user'
# - text='Is your previous passport available?' participant='assistant'
# - text='I brought my previous passport' participant='user'
# - text='Is the application form completed?' participant='assistant'
# - text='Yes, I have the form filled out' participant='user'
# - text='Have you brought a new passport photo?' participant='assistant'
# - text='Yes, I have my photo' participant='user'
# - text='Your application is complete. Anything else?' participant='assistant'
# - text="Yes, that's all I need" participant='user'
# - text='Thank you for your application. Have a great day!' participant='assistant'
# --------------------------------------------------
#
# Topic: driving lesson booking
#
# Path 1:
# - text='How can I assist you with your driving lessons today?' participant='assistant'
# - text='I want to book a driving lesson' participant='user'
# - text='What is your current driving experience?' participant='assistant'
# - text='I have some experience' participant='user'
# - text='What days are you free for lessons?' participant='assistant'
# - text='I prefer weekends' participant='user'
# - text='You want lessons on weekdays, right?' participant='assistant'
# - text='Yes, that works for me' participant='user'
# - text="I've scheduled your lesson. Anything more?" participant='assistant'
# - text="I'd like to schedule another session" participant='user'
#
# Path 2:
# - text='How can I assist you with your driving lessons today?' participant='assistant'
# - text='I want to book a driving lesson' participant='user'
# - text='What is your current driving experience?' participant='assistant'
# - text='I have some experience' participant='user'
# - text='What days are you free for lessons?' participant='assistant'
# - text='I prefer weekends' participant='user'
# - text='So, you prefer weekdays, correct?' participant='assistant'
# - text='Yes, that sounds good' participant='user'
# - text="I've scheduled your lesson. Anything more?" participant='assistant'
# - text="I'd like to schedule another session" participant='user'
#
# Path 3:
# - text='How can I assist you with your driving lessons today?' participant='assistant'
# - text="I'd like to schedule a driving lesson" participant='user'
# - text='How much driving experience do you have?' participant='assistant'
# - text="I've driven before" participant='user'
# - text='What days are you free for lessons?' participant='assistant'
# - text='I prefer weekends' participant='user'
# - text='You want lessons on weekdays, right?' participant='assistant'
# - text='Yes, that sounds good' participant='user'
# - text='Your lesson is booked. Anything else?' participant='assistant'
# - text='I want to book another lesson' participant='user'
# --------------------------------------------------
#
# Topic: moving service scheduling
#
# Path 1:
# - text='How can I assist you with your move?' participant='assistant'
# - text='I want to book a moving service' participant='user'
# - text='When are you planning to move?' participant='assistant'
# - text="I'm moving next Friday" participant='user'
# - text='How big is your current place?' participant='assistant'
# - text='I have a two-bedroom apartment' participant='user'
# - text="You're moving a two-bedroom home next Friday, right?" participant='assistant'
# - text="Yes, that's right" participant='user'
# - text='The booking is complete. Do you need anything else?' participant='assistant'
# - text='I need to change the date' participant='user'
#
# Path 2:
# - text='How can I assist you with your move?' participant='assistant'
# - text='I need to schedule a move' participant='user'
# - text='When are you planning to move?' participant='assistant'
# - text="I'm moving next Friday" participant='user'
# - text='How big is your current place?' participant='assistant'
# - text='I have a two-bedroom apartment' participant='user'
# - text='So, a two-bedroom move next Friday, correct?' participant='assistant'
# - text="Yes, that's correct" participant='user'
# - text='Your move is scheduled. Anything else?' participant='assistant'
# - text='I need to change the date' participant='user'
#
# Path 3:
# - text='What can I do for your moving needs?' participant='assistant'
# - text='I want to book a moving service' participant='user'
# - text='When are you planning to move?' participant='assistant'
# - text="I'm moving next Friday" participant='user'
# - text='How big is your current place?' participant='assistant'
# - text='I have a two-bedroom apartment' participant='user'
# - text="You're moving a two-bedroom home next Friday, right?" participant='assistant'
# - text="Yes, that's correct" participant='user'
# - text='Your move is scheduled. Anything else?' participant='assistant'
# - text='I want to reschedule' participant='user'
# --------------------------------------------------
#
# Topic: home cleaning service bookingbeauty salon appointment
#
# Path 1:
# - text='What cleaning service can I help you with today?' participant='assistant'
# - text='I need to book a cleaning service' participant='user'
# - text='What date do you need the cleaning?' participant='assistant'
# - text='Can I book it for tomorrow?' participant='user'
# - text='So, you want it for tomorrow, correct?' participant='assistant'
# - text='That works for me' participant='user'
# - text='What type of cleaning do you need?' participant='assistant'
# - text="I'd like a thorough cleaning" participant='user'
# - text='A deep cleaning, is that correct?' participant='assistant'
# - text='Yes, please' participant='user'
# - text='Your booking is confirmed. Anything else?' participant='assistant'
# - text="I'd like to schedule something else" participant='user'
#
# Path 2:
# - text='What cleaning service can I help you with today?' participant='assistant'
# - text='I need to book a cleaning service' participant='user'
# - text='What date do you need the cleaning?' participant='assistant'
# - text='I need it for tomorrow' participant='user'
# - text='So, you want it for tomorrow, correct?' participant='assistant'
# - text="Yes, that's fine" participant='user'
# - text='What type of cleaning do you need?' participant='assistant'
# - text="I'd like a thorough cleaning" participant='user'
# - text='A deep cleaning, is that correct?' participant='assistant'
# - text='That sounds good' participant='user'
# - text='Your booking is confirmed. Anything else?' participant='assistant'
# - text='I want to book another service' participant='user'
#
# Path 3:
# - text='How can I assist you with your cleaning needs today?' participant='assistant'
# - text='I need to book a cleaning service' participant='user'
# - text='When would you like the cleaning service?' participant='assistant'
# - text='Can I book it for tomorrow?' participant='user'
# - text="You'd like the service scheduled for tomorrow, right?" participant='assistant'
# - text="Yes, that's fine" participant='user'
# - text='Which cleaning service are you interested in?' participant='assistant'
# - text='I need a deep cleaning' participant='user'
# - text='You want a thorough cleaning, right?' participant='assistant'
# - text='Yes, please' participant='user'
# - text='The service is scheduled. Would you like anything else?' participant='assistant'
# - text='I want to book another service' participant='user'
# --------------------------------------------------
#
# Topic: bank account opening
#
# Path 1:
# - text='Hello! What can I help you with today?' participant='assistant'
# - text="I'd like to set up a new account" participant='user'
# - text='What type of account are you looking to open?' participant='assistant'
# - text="I'm interested in a savings account" participant='user'
# - text='Do you have your identification documents with you?' participant='assistant'
# - text='Yes, I have my ID with me' participant='user'
# - text='Do you need assistance with anything else?' participant='assistant'
# - text="No, that's everything for now" participant='user'
# - text='Your account setup is complete. Have a great day!' participant='assistant'
# - text="I'd like to set up a different account" participant='user'
#
# Path 2:
# - text='Welcome to our bank. How can I assist you today?' participant='assistant'
# - text='I want to open a bank account' participant='user'
# - text='What type of account are you looking to open?' participant='assistant'
# - text='I need a savings account' participant='user'
# - text='Are your ID documents ready?' participant='assistant'
# - text='Yes, I have my ID with me' participant='user'
# - text='Is there anything else you need help with?' participant='assistant'
# - text="No, that's everything for now" participant='user'
# - text='Your account setup is complete. Have a great day!' participant='assistant'
# - text='I want to open another account' participant='user'
#
# Path 3:
# - text='Hello! What can I help you with today?' participant='assistant'
# - text='I want to open a bank account' participant='user'
# - text='Which account would you like to set up?' participant='assistant'
# - text="I'm interested in a savings account" participant='user'
# - text='Do you have your identification documents with you?' participant='assistant'
# - text='I have my identification ready' participant='user'
# - text='Is there anything else you need help with?' participant='assistant'
# - text="No, that's everything for now" participant='user'
# - text='Everything is set up. Enjoy your day!' participant='assistant'
# - text='I want to open another account' participant='user'
# --------------------------------------------------
#
# Processing file: valid_dialogues_two_utter_20241127_221403.json
# ================================================================================
#
# Topic: dental appointment scheduling
#
# Path 1:
# - text='What can I help you with today?' participant='assistant'
# - text="I'd like to book a dental visit" participant='user'
# - text='When would you like to come in?' participant='assistant'
# - text='Next week works for me' participant='user'
# - text='Do you have a preferred time?' participant='assistant'
# - text='I prefer the morning' participant='user'
# - text='So, a morning appointment next week, correct?' participant='assistant'
# - text="Yes, that's fine" participant='user'
# - text='All scheduled. Do you need anything else?' participant='assistant'
# - text='I need to schedule another appointment' participant='user'
#
# Path 2:
# - text='How can I assist you today?' participant='assistant'
# - text="I'd like to book a dental visit" participant='user'
# - text='What date works for you?' participant='assistant'
# - text='I prefer next week' participant='user'
# - text='Do you have a preferred time?' participant='assistant'
# - text='I prefer the morning' participant='user'
# - text='You want a morning slot next week, right?' participant='assistant'
# - text="Yes, that's fine" participant='user'
# - text='All scheduled. Do you need anything else?' participant='assistant'
# - text="I'd like to book another visit" participant='user'
#
# Path 3:
# - text='What can I help you with today?' participant='assistant'
# - text='I need to schedule a dental appointment' participant='user'
# - text='When would you like to come in?' participant='assistant'
# - text='Next week works for me' participant='user'
# - text='Do you have a preferred time?' participant='assistant'
# - text='I prefer the morning' participant='user'
# - text='You want a morning slot next week, right?' participant='assistant'
# - text='Yes, that works' participant='user'
# - text='Your appointment is set. Anything else?' participant='assistant'
# - text='I need to schedule another appointment' participant='user'
# --------------------------------------------------
#
# Topic: internet installation setup
#
# Path 1:
# - text='How can I assist you with your internet today?' participant='assistant'
# - text='I need help setting up my internet' participant='user'
# - text='Have you received the installation kit?' participant='assistant'
# - text='I have the installation kit' participant='user'
# - text='Have you plugged in all the cables?' participant='assistant'
# - text="No, I haven't plugged it in yet" participant='user'
# - text='Ensure all cables are securely plugged in' participant='assistant'
# - text='I have connected it now' participant='user'
# - text='Have you plugged in all the cables?' participant='assistant'
# - text="Yes, it's connected" participant='user'
# - text='Do you see any lights on the router?' participant='assistant'
# - text='Yes, the indicators are lit' participant='user'
# - text='Can you access the internet now?' participant='assistant'
# - text='Yes, I am online' participant='user'
# - text='Great! Is there anything else you need?' participant='assistant'
# - text="No, I'm good" participant='user'
# - text='Thank you for choosing our service!' participant='assistant'
#
# Path 2:
# - text='What can I help you with regarding your internet?' participant='assistant'
# - text='I want to install my internet service' participant='user'
# - text='Have you received the installation kit?' participant='assistant'
# - text='I have the installation kit' participant='user'
# - text='Have you plugged in all the cables?' participant='assistant'
# - text="No, I haven't plugged it in yet" participant='user'
# - text='Ensure all cables are securely plugged in' participant='assistant'
# - text='I have plugged it in now' participant='user'
# - text='Have you plugged in all the cables?' participant='assistant'
# - text="Yes, it's connected" participant='user'
# - text='Are the lights on the modem lit?' participant='assistant'
# - text='Yes, the indicators are lit' participant='user'
# - text='Are you able to go online?' participant='assistant'
# - text='Yes, I am online' participant='user'
# - text='Awesome! Do you need help with anything else?' participant='assistant'
# - text="No, I'm good" participant='user'
# - text='Thanks for using our service!' participant='assistant'
#
# Path 3:
# - text='What can I help you with regarding your internet?' participant='assistant'
# - text='I need help setting up my internet' participant='user'
# - text='Do you have the necessary equipment?' participant='assistant'
# - text='I have the equipment' participant='user'
# - text='Is everything connected properly?' participant='assistant'
# - text="No, I haven't plugged it in yet" participant='user'
# - text='Please connect the cables as per the guide' participant='assistant'
# - text='I have plugged it in now' participant='user'
# - text='Have you plugged in all the cables?' participant='assistant'
# - text="Yes, it's connected" participant='user'
# - text='Are the lights on the modem lit?' participant='assistant'
# - text='Yes, the lights are on' participant='user'
# - text='Are you able to go online?' participant='assistant'
# - text='Yes, I can access the internet' participant='user'
# - text='Awesome! Do you need help with anything else?' participant='assistant'
# - text="No, I'm good" participant='user'
# - text='Thanks for using our service!' participant='assistant'
# --------------------------------------------------
#
# Topic: visa application consultation
#
# Path 1:
# - text='How can I assist you with your visa application?' participant='assistant'
# - text="I'm looking for advice on applying for a visa" participant='user'
# - text='What type of visa are you applying for?' participant='assistant'
# - text='I need a tourist visa' participant='user'
# - text='Have you prepared all the required documents?' participant='assistant'
# - text='I have all the required documents' participant='user'
# - text="Alright, here's what you need to do next" participant='assistant'
# - text='I got it, thank you' participant='user'
# - text='Is there anything else you need help with?' participant='assistant'
# - text='I need to ask something else' participant='user'
#
# Path 2:
# - text='How can I assist you with your visa application?' participant='assistant'
# - text='I need help with a visa application' participant='user'
# - text='What type of visa are you applying for?' participant='assistant'
# - text="I'm applying for a tourist visa" participant='user'
# - text='Do you have all the necessary documents?' participant='assistant'
# - text='I have gathered all necessary paperwork' participant='user'
# - text="Alright, here's what you need to do next" participant='assistant'
# - text='Yes, I understand' participant='user'
# - text='Is there anything else you need help with?' participant='assistant'
# - text='I have another question' participant='user'
#
# Path 3:
# - text='What can I help you with regarding your visa?' participant='assistant'
# - text="I'm looking for advice on applying for a visa" participant='user'
# - text='Which visa category are you interested in?' participant='assistant'
# - text='I need a tourist visa' participant='user'
# - text='Have you prepared all the required documents?' participant='assistant'
# - text='I have gathered all necessary paperwork' participant='user'
# - text="Alright, here's what you need to do next" participant='assistant'
# - text='Yes, I understand' participant='user'
# - text='Do you have any other questions?' participant='assistant'
# - text='I need to ask something else' participant='user'
# --------------------------------------------------

# %%
from langchain.prompts import PromptTemplate
from langchain.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field
import json
import logging

from langchain_core.language_models.chat_models import BaseChatModel

def are_triplets_valid_new(G: Graph, model: BaseChatModel) -> dict[str]:
    """
    Validates dialogue graph structure and logical transitions between nodes.
    
    Parameters:
        G (BaseGraph): The dialogue graph to validate
        model (BaseChatModel): The LLM model to use for validation
    
    Returns:
        dict: {'value': bool, 'description': str}
    """
    # Define validation result model
    class TransitionValidationResult(BaseModel):
        isValid: bool = Field(description="Whether the transition is valid or not")
        description: str = Field(description="Explanation of why it's valid or invalid")

    # Create prompt template
    triplet_validate_prompt_template = """
    You are evaluating if dialog transitions make logical sense.
    
    Given this conversation graph in JSON:
    {json_graph}
    
    For the current transition:
    Source (Assistant): {source_utterances}
    User Response: {edge_utterances}
    Target (Assistant): {target_utterances}

    EVALUATE: Do these three messages form a logical sequence in the conversation?
    Consider:
    1. Does the assistant's first response naturally lead to the user's response?
    2. Does the user's response logically connect to the assistant's next message?
    3. Is the overall flow natural and coherent?

    Reply in JSON format:
    {{"isValid": true/false, "description": "Brief explanation of why it's valid or invalid"}}
    """

    triplet_validate_prompt = PromptTemplate(
        input_variables=["json_graph", "source_utterances", "edge_utterances", "target_utterances"],
        template=triplet_validate_prompt_template
    )

    parser = PydanticOutputParser(pydantic_object=TransitionValidationResult)
    
    # Convert graph to JSON string
    graph_json = json.dumps(G.graph_dict)
    
    # Create node mapping
    node_map = {node["id"]: node for node in G.graph_dict["nodes"]}
    
    overall_valid = True
    descriptions = []

    for edge in G.graph_dict["edges"]:
        source_id = edge["source"]
        target_id = edge["target"]
        
        if source_id not in node_map or target_id not in node_map:
            description = f"Invalid edge: missing node reference {source_id} -> {target_id}"
            overall_valid = False
            descriptions.append(description)
            continue

        # Get utterances
        source_utterances = node_map[source_id]["utterances"]
        target_utterances = node_map[target_id]["utterances"]
        edge_utterances = edge["utterances"]

        # Prepare input for validation
        input_data = {
            "json_graph": graph_json,
            "source_utterances": source_utterances,
            "edge_utterances": edge_utterances,
            "target_utterances": target_utterances
        }

        # Run validation
        triplet_check_chain = triplet_validate_prompt | model | parser
        response = triplet_check_chain.invoke(input_data)

        if not response.isValid:
            overall_valid = False
            description = f"Invalid transition: {response.description}"
            logging.info(description)
            descriptions.append(description)

    result = {
        "value": overall_valid,
        "description": " ".join(descriptions) if descriptions else "All transitions are valid."
    }
    
    return result

# %%
from chatsky_llm_autoconfig.algorithms.dialogue_generation import DialogueSampler
from chatsky_llm_autoconfig.graph import Graph
from langchain_openai import ChatOpenAI
from pathlib import Path
import json
from typing import Dict, Any, List
from datetime import datetime

def evaluate_dataset(file_path: Path, model: ChatOpenAI) -> Dict[str, Any]:
    """Evaluate a single dataset file and return metrics."""
    with open(file_path, 'r') as f:
        data = json.load(f)
    
    total_graphs = len(data)
    valid_count = 0
    invalid_transitions = []
    results_by_topic = {}
    
    for entry in data:
        topic = entry['topic']
        graph = Graph(entry['graph'])
        
        # Run new validation
        validation_result = are_triplets_valid_new(graph, model)
        
        # Store results by topic
        results_by_topic[topic] = {
            'is_valid': validation_result['value'],
            'description': validation_result['description']
        }
        
        if validation_result['value']:
            valid_count += 1
        else:
            invalid_transitions.append({
                'topic': topic,
                'description': validation_result['description']
            })
    
    metrics = {
        'file_name': file_path.name,
        'total_graphs': total_graphs,
        'valid_graphs': valid_count,
        'invalid_graphs': total_graphs - valid_count,
        'validity_rate': valid_count / total_graphs if total_graphs > 0 else 0,
        'results_by_topic': results_by_topic,
        'invalid_transitions': invalid_transitions
    }
    
    return metrics

def compare_datasets():
    # Initialize model
    model = ChatOpenAI(
        model='gpt-4',
        api_key=os.getenv("OPENAI_API_KEY"),
        base_url=os.getenv("OPENAI_BASE_URL"),
        temperature=0
    )
    
    # Get both dataset files
    dataset_dir = Path("generated_datasets")
    timestamp = "20241127_215908"  # Update with your timestamp
    valid_file = dataset_dir / f"valid_dialogues_{timestamp}.json"
    invalid_file = dataset_dir / f"invalid_dialogues_{timestamp}.json"
    
    # Evaluate both datasets
    valid_metrics = evaluate_dataset(valid_file, model)
    invalid_metrics = evaluate_dataset(invalid_file, model)
    
    # Create comparison report
    timestamp_now = datetime.now().strftime("%Y%m%d_%H%M%S")
    report = {
        'timestamp': timestamp_now,
        'valid_dataset_metrics': valid_metrics,
        'invalid_dataset_metrics': invalid_metrics,
        'comparison': {
            'agreement_rate_valid': valid_metrics['validity_rate'],
            'agreement_rate_invalid': 1 - invalid_metrics['validity_rate'],
            'overall_agreement': (valid_metrics['validity_rate'] + (1 - invalid_metrics['validity_rate'])) / 2
        }
    }
    
    # Save report
    report_file = dataset_dir / f"validation_report_{timestamp_now}.json"
    with open(report_file, 'w', encoding='utf-8') as f:
        json.dump(report, f, ensure_ascii=False, indent=2)
    
    # Print summary
    print("\nValidation Summary:")
    print("=" * 50)
    print(f"Valid Dataset ({valid_file.name}):")
    print(f"- Total graphs: {valid_metrics['total_graphs']}")
    print(f"- Valid graphs: {valid_metrics['valid_graphs']}")
    print(f"- Validity rate: {valid_metrics['validity_rate']:.2%}")
    print(f"\nInvalid Dataset ({invalid_file.name}):")
    print(f"- Total graphs: {invalid_metrics['total_graphs']}")
    print(f"- Valid graphs: {invalid_metrics['valid_graphs']}")
    print(f"- Validity rate: {invalid_metrics['validity_rate']:.2%}")
    print(f"\nOverall Agreement: {report['comparison']['overall_agreement']:.2%}")
    print(f"\nDetailed report saved to: {report_file}")

    return report

# Run comparison
if __name__ == "__main__":
    report = compare_datasets()
# Out:
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:openai._base_client:Retrying request to /chat/completions in 0.400617 seconds
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:openai._base_client:Retrying request to /chat/completions in 0.774940 seconds
# INFO:httpx:HTTP Request: POST http://193.187.173.33:8002/api/providers/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[20], line 107
#     105 # Run comparison
#     106 if __name__ == "__main__":
# --> 107     report = compare_datasets()
#
# Cell In[20], line 68, in compare_datasets()
#      65 invalid_file = dataset_dir / f"invalid_dialogues_{timestamp}.json"
#      67 # Evaluate both datasets
# ---> 68 valid_metrics = evaluate_dataset(valid_file, model)
#      69 invalid_metrics = evaluate_dataset(invalid_file, model)
#      71 # Create comparison report
#
# Cell In[20], line 24, in evaluate_dataset(file_path, model)
#      21 graph = Graph(entry['graph'])
#      23 # Run new validation
# ---> 24 validation_result = are_triplets_valid_new(graph, model)
#      26 # Store results by topic
#      27 results_by_topic[topic] = {
#      28     'is_valid': validation_result['value'],
#      29     'description': validation_result['description']
#      30 }
#
# Cell In[19], line 88, in are_triplets_valid_new(G, model)
#      86 # Run validation
#      87 triplet_check_chain = triplet_validate_prompt | model | parser
# ---> 88 response = triplet_check_chain.invoke(input_data)
#      90 if not response.isValid:
#      91     overall_valid = False
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:707, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     705     generation_info = {"headers": dict(raw_response.headers)}
#     706 else:
# --> 707     response = self.client.create(**payload)
#     708 return self._create_chat_result(response, generation_info)
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/resources/chat/completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     788 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     789 def create(
#     790     self,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     828     validate_response_format(response_format)
# --> 829     return self._post(
#     830         "/chat/completions",
#     831         body=maybe_transform(
#     832             {
#     833                 "messages": messages,
#     834                 "model": model,
#     835                 "audio": audio,
#     836                 "frequency_penalty": frequency_penalty,
#     837                 "function_call": function_call,
#     838                 "functions": functions,
#     839                 "logit_bias": logit_bias,
#     840                 "logprobs": logprobs,
#     841                 "max_completion_tokens": max_completion_tokens,
#     842                 "max_tokens": max_tokens,
#     843                 "metadata": metadata,
#     844                 "modalities": modalities,
#     845                 "n": n,
#     846                 "parallel_tool_calls": parallel_tool_calls,
#     847                 "prediction": prediction,
#     848                 "presence_penalty": presence_penalty,
#     849                 "response_format": response_format,
#     850                 "seed": seed,
#     851                 "service_tier": service_tier,
#     852                 "stop": stop,
#     853                 "store": store,
#     854                 "stream": stream,
#     855                 "stream_options": stream_options,
#     856                 "temperature": temperature,
#     857                 "tool_choice": tool_choice,
#     858                 "tools": tools,
#     859                 "top_logprobs": top_logprobs,
#     860                 "top_p": top_p,
#     861                 "user": user,
#     862             },
#     863             completion_create_params.CompletionCreateParams,
#     864         ),
#     865         options=make_request_options(
#     866             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867         ),
#     868         cast_to=ChatCompletion,
#     869         stream=stream or False,
#     870         stream_cls=Stream[ChatCompletionChunk],
#     871     )
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/_base_client.py:1043, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1041 if remaining_retries > 0 and self._should_retry(err.response):
#    1042     err.response.close()
# -> 1043     return self._retry_request(
#    1044         input_options,
#    1045         cast_to,
#    1046         retries_taken=retries_taken,
#    1047         response_headers=err.response.headers,
#    1048         stream=stream,
#    1049         stream_cls=stream_cls,
#    1050     )
#    1052 # If the response is streamed then we need to explicitly read the response
#    1053 # to completion before attempting to access the response text.
#    1054 if not err.response.is_closed:
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/_base_client.py:1092, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1088 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1089 # different thread if necessary.
#    1090 time.sleep(timeout)
# -> 1092 return self._request(
#    1093     options=options,
#    1094     cast_to=cast_to,
#    1095     retries_taken=retries_taken + 1,
#    1096     stream=stream,
#    1097     stream_cls=stream_cls,
#    1098 )
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/_base_client.py:1043, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1041 if remaining_retries > 0 and self._should_retry(err.response):
#    1042     err.response.close()
# -> 1043     return self._retry_request(
#    1044         input_options,
#    1045         cast_to,
#    1046         retries_taken=retries_taken,
#    1047         response_headers=err.response.headers,
#    1048         stream=stream,
#    1049         stream_cls=stream_cls,
#    1050     )
#    1052 # If the response is streamed then we need to explicitly read the response
#    1053 # to completion before attempting to access the response text.
#    1054 if not err.response.is_closed:
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/_base_client.py:1092, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1088 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1089 # different thread if necessary.
#    1090 time.sleep(timeout)
# -> 1092 return self._request(
#    1093     options=options,
#    1094     cast_to=cast_to,
#    1095     retries_taken=retries_taken + 1,
#    1096     stream=stream,
#    1097     stream_cls=stream_cls,
#    1098 )
#
# File ~/Documents/Projects/deeppavlov/chatsky-llm-autoconfig/.venv/lib/python3.12/site-packages/openai/_base_client.py:1058, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1055         err.response.read()
#    1057     log.debug("Re-raising status error")
# -> 1058     raise self._make_status_error_from_response(err.response) from None
#    1060 return self._process_response(
#    1061     cast_to=cast_to,
#    1062     options=options,
#    (...)
#    1066     retries_taken=retries_taken,
#    1067 )
#
# RateLimitError: Error code: 429 - {'error': {'code': '429', 'message': '[BricksLLM] too many requests', 'type': ''}}
