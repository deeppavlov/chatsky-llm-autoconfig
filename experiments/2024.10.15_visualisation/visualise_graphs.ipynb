# %%
import json
from chatsky_llm_autoconfig.evaluate import visualize_graph
import matplotlib.pyplot as plt

# %%
with open('/home/askatasuna/Документы/DeepPavlov/chatsky-llm-autoconfig/data/data.json') as f:
    data = json.load(f)

# %%
for i in data:
    plt.figure(figsize=(20, 10))
    visualize_graph(i['target_graph'], i['samping_method'])
    plt.savefig(f"img/{i['samping_method']}")
